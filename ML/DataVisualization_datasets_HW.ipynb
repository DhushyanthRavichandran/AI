# %% [markdown]
# <a href="https://colab.research.google.com/github/DhushyanthRavichandran/AI/blob/main/ML/DataVisualization_datasets_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/world_population.csv')
#data.info()

# %%
data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
data.replace(0.00,np.nan,inplace=True)
data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
data.isnull().sum()
# Out:
# Rank                            0
# CCA3                            0
# Country/Territory               0
# Capital                         0
# Continent                       0
# 2022 Population                 0
# 2020 Population                 0
# 2015 Population                 0
# 2010 Population                 0
# 2000 Population                 0
# 1990 Population                 0
# 1980 Population                 0
# 1970 Population                 0
# Area (km²)                      0
# Density (per km²)               0
# Growth Rate                     0
# World Population Percentage    57
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
# THERE is no duplicate datas

# %%
mean=data['World Population Percentage'].mean()
mean
# Out:
# 0.5645762711864407

# %%
data['World Population Percentage'].replace(np.nan,mean,inplace=True)
data
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
data.sort_values(['Rank'],inplace=True)
data
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# ..    ...  ...               ...               ...            ...
# 137   230  MSR        Montserrat            Brades  North America
# 64    231  FLK  Falkland Islands           Stanley  South America
# 150   232  NIU              Niue             Alofi        Oceania
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 226   234  VAT      Vatican City      Vatican City         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# ...

# %%
data.reset_index(drop=True,inplace=True)
data
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 0       1  CHN             China           Beijing           Asia
# 1       2  IND             India         New Delhi           Asia
# 2       3  USA     United States  Washington, D.C.  North America
# 3       4  IDN         Indonesia           Jakarta           Asia
# 4       5  PAK          Pakistan         Islamabad           Asia
# ..    ...  ...               ...               ...            ...
# 229   230  MSR        Montserrat            Brades  North America
# 230   231  FLK  Falkland Islands           Stanley  South America
# 231   232  NIU              Niue             Alofi        Oceania
# 232   233  TKL           Tokelau          Nukunonu        Oceania
# 233   234  VAT      Vatican City      Vatican City         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         1425887337       1424929781       1393715448       1348191368
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
'''scalar= MinMaxScaler()
for i in ['2022 Population','2020 Population','2015 Population','2010 Population','2000 Population','1990 Population','1980 Population','1970 Population']:
  data[i]=scalar.fit_transform(data[[i]])'''
# Out:
# "scalar= MinMaxScaler()\nfor i in ['2022 Population','2020 Population','2015 Population','2010 Population','2000 Population','1990 Population','1980 Population','1970 Population']:\n  data[i]=scalar.fit_transform(data[[i]])"

# %%
#data

# %%
'''import matplotlib.pyplot as plt
#plt.figure(figsize=(100, 25))
sns.boxplot(data[	'2022 Population'],orient='h')

plt.ylim(0, 10)
plt.show()
'''
# Out:
# "import matplotlib.pyplot as plt\n#plt.figure(figsize=(100, 25))\nsns.boxplot(data[\t'2022 Population'],orient='h')\n\nplt.ylim(0, 10)\nplt.show()\n"

# %% [markdown]
# import tensorflow as tfs

# %%
import tensorflow as tfs
from scipy import stats

dzscore=abs(stats.zscore(data['2022 Population']))
threshold=dzscore.max()
threshold
# Out:
# 10.198383481260134

# %%
index_value=np.where(dzscore>=threshold)
data.iloc[index_value]['2022 Population']
# Out:
# 0    1425887337
# Name: 2022 Population, dtype: int64

# %%
data.plot.bar()
# Out:
# <Axes: >

# %%
#data_pie.plot.pie(subplots=True)

# %%
data=data.rename(columns={'2022 Population':'2022',	'2020 Population':'2020','2015 Population':'2015','2010 Population':'2010',	'2000 Population':'2000','1990 Population':'1990',	'1980 Population':'1980','1970 Population':'1970'})

# %%
asia=data[data.Continent=='Asia']

# %%
asiadata=asia.drop(columns=['Rank','Area (km²)','Density (per km²)','Growth Rate','World Population Percentage'])

# %%
#asiadata

# %%
asiadata=asiadata.head(30)

# %%
sns.barplot(data=asiadata)
# Out:
# <Axes: >

# %%
data.sort_values('Continent')
sns.barplot(x='Continent', y='Growth Rate',data=data)
# Out:
# <Axes: xlabel='Continent', ylabel='Growth Rate'>

# %%
sns.pointplot(x='Continent', y='Growth Rate',data=data)
# Out:
# <Axes: xlabel='Continent', ylabel='Growth Rate'>

# %%
top15countrywp=data.head(15)
top15countrywp
# Out:
#     Rank CCA3 Country/Territory           Capital      Continent        2022  \
# 0      1  CHN             China           Beijing           Asia  1425887337
# 1      2  IND             India         New Delhi           Asia  1417173173
# 2      3  USA     United States  Washington, D.C.  North America   338289857
# 3      4  IDN         Indonesia           Jakarta           Asia   275501339
# 4      5  PAK          Pakistan         Islamabad           Asia   235824862
# 5      6  NGA           Nigeria             Abuja         Africa   218541212
# 6      7  BRA            Brazil          Brasilia  South America   215313498
# 7      8  BGD        Bangladesh             Dhaka           Asia   171186372
# 8      9  RUS            Russia            Moscow         Europe   144713314
# 9     10  MEX            Mexico       Mexico City  North America   127504125
# 10    11  JPN             Japan             Tokyo           Asia   123951692
# ...

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data=top15countrywp,x='Country/Territory',y='World Population Percentage')
# Out:
# <Axes: xlabel='Country/Territory', ylabel='World Population Percentage'>

# %%
plt.pie(top15countrywp['1990'],labels=top15countrywp['Country/Territory'])
plt.plot()
# Out:
# []

# %%
data_area=data.sort_values(['Area (km²)'],ascending=False).head(15)

# %%
plt.pie(data_area['Area (km²)'],labels=data_area['Country/Territory'])
plt.plot()
# Out:
# []

# %%
sns.barplot(data=data.head(15),x='Country/Territory',y='Rank')
plt.plot()
# Out:
# []

# %%
sns.boxplot(data[	'2022'])
# Out:
# <Axes: >
